# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanfoo0710-ai/P300-BCI-Project/blob/main/bigP3BCI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The '!' tells Colab to run a terminal command
# This downloads ONLY the files in the 'StudyA' folder to the Colab temporary disk
# !wget -r -N -c -np https://physionet.org/files/bigp3bci/1.0.0/
# Out:
# Streaming output truncated to the last 5000 lines.
# Last-modified header missing -- time-stamps turned off.
# 2026-03-14 03:37:34 (94.1 MB/s) - ‘physionet.org/files/bigp3bci/1.0.0/bigP3BCI-data/StudyO/O_14/SE002/Train/index.html’ saved [408]
#
# --2026-03-14 03:37:34--  https://physionet.org/files/bigp3bci/1.0.0/bigP3BCI-data/StudyO/O_15/SE001/Test/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/bigp3bci/1.0.0/bigP3BCI-data/StudyO/O_15/SE001/Test/index.html’
#
# physionet.org/files     [ <=>                ]     406  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2026-03-14 03:37:34 (121 MB/s) - ‘physionet.org/files/bigp3bci/1.0.0/bigP3BCI-data/StudyO/O_15/SE001/Test/index.html’ saved [406]
#
# --2026-03-14 03:37:34--  https://physionet.org/files/bigp3bci/1.0.0/bigP3BCI-data/StudyO/O_15/SE001/Train/
# ...

# %%
# !ls physionet.org/files/bigp3bci/1.0.0/StudyA/
